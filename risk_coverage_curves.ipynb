# %% [markdown]
# <a href="https://colab.research.google.com/github/AoShuang92/PhD_tutorial/blob/main/risk_coverage_curves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

Coverage = np.array([0.9, 0.85	, 0.8, 0.75	, 0.7, 0.65	, 0.6, 0.55	, 0.5])
BS = np.array([78,	75.7,	73,	71,	68.2,	65.6,	63.2,	60.7,	57.2])	
TS = np.array([76.7,	75.8,	70.3,	70.4,	66.9,	63.1,	61.9,	58.7,	56.8])	
MCS_TS = np.array([78.4,	75.8,	73,	70.3,	68.3,	65.9,	63.4,	60.9,	57.9])	
all_error = np.array([BS, TS, MCS_TS])
# plt.plot(Coverage, all_error.transpose())
ax = plt.gca()
lineObjects = ax.plot(Coverage, all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS_TS']
ax.legend(lineObjects, legends)
ax.set_ylabel('Selective Risk (%)')
ax.set_xlabel("Coverage")
ax.set_title('Risk-coverage curve for CIFAR100');
plt.savefig("Risk_coverage_curve_CIFAR100.pdf", bbox_inches='tight', dpi=1500)

# %%
import numpy as np
import matplotlib.pyplot as plt

Coverage = np.array([0.9, 0.85	, 0.8, 0.75	, 0.7, 0.65	, 0.6, 0.55	, 0.5])
BS = np.array([59.3,	54.4,	51.2,	47.3,	44.3,	40.9,	37.4,	34.4,	31.7])
TS = np.array([57.8,	53.3,	49.9,	46.3,	42.8,	40.4,	37.1,	34.3,	31.6])
MCS_TS = np.array ([58.4,	54.2,	50.9,	47.3,	44.2,	40.8,	38,	34.9,	32])
all_error = np.array([BS, TS, MCS_TS])

ax = plt.gca()
lineObjects = ax.plot(Coverage, all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS_TS']
ax.legend(lineObjects, legends)
ax.set_ylabel('Selective Risk (%)')
ax.set_xlabel("Coverage")
ax.set_title('Risk-coverage curve for ImageNet ViT');
plt.savefig("Risk_coverage_curve_ImageNet_ViT.pdf", bbox_inches='tight', dpi=1500)

# %%
Coverage = np.array([0.9, 0.85	, 0.8, 0.75	, 0.7, 0.65	, 0.6, 0.55	, 0.5])
BS = np.array([52.5,	47.2,	43.2,	39.8,	37,	34.5,	32.3,	29.9,	27.8])
TS = np.array([52.5,	47.6,	44,	40.1,	38,	34.9,	32.2,	30.1,	27.4])
MCS_TS = np.array([55.1,	50,	46.2,	43.3,	40.1,	36.8,	34,	31.2,	27.8])
all_error = np.array([BS, TS, MCS_TS])

ax = plt.gca()
lineObjects = ax.plot(Coverage, all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS_TS']
ax.legend(lineObjects, legends)
ax.set_ylabel('Selective Risk (%)')
ax.set_xlabel("Coverage")
ax.set_title('Risk-coverage curve for ImageNet Swin Transformers');
plt.savefig("Risk_coverage_curve_ImageNet_ViT.pdf", bbox_inches='tight', dpi=1500)

# %%
Coverage = np.array([0.9, 0.85	, 0.8, 0.75	, 0.7, 0.65	, 0.6, 0.55	, 0.5])
BS = np.array([76.5,	72.5,	68.8,	65.6,	62.1,	59.2,	56.6,	54.2,	51.3])
TS = np.array([74.9,	71.2,	67.7,	64.3,	61.1,	58.3,	55.3,	53.2,	50.1])
MCS_TS = np.array([75.4,	71.9,	68.9,	65.3,	62.5,	59.3,	56.2,	54.5,	50.9])
all_error = np.array([BS, TS, MCS_TS])

ax = plt.gca()
lineObjects = ax.plot(Coverage, all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS_TS']
ax.legend(lineObjects, legends)
ax.set_ylabel('Selective Risk (%)')
ax.set_xlabel("Coverage")
ax.set_title('Risk-coverage curve for ImageNet ResNet34');
plt.savefig("Risk_coverage_curve_ImageNet_ResNet34.pdf", bbox_inches='tight', dpi=1500)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 4, figsize=(18, 4), gridspec_kw=dict(wspace=0.2, hspace=0.3))

Coverage = np.array([0.9, 0.85	, 0.8, 0.75	, 0.7, 0.65	, 0.6, 0.55	, 0.5])
cifar_BS = np.array([78,	75.7,	73,	71,	68.2,	65.6,	63.2,	60.7,	57.2])	
cifar_TS = np.array([76.7,	75.8,	70.3,	70.4,	66.9,	63.1,	61.9,	58.7,	56.8])	
cifar_MCS_TS = np.array([78.4,	75.8,	73,	70.3,	68.3,	65.9,	63.4,	60.9,	57.9])	
all_error_cifar100 = np.array([cifar_BS, cifar_TS, cifar_MCS_TS])

lineObjects = ax[0].plot(Coverage, all_error_cifar100.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS TS']
ax[0].legend(lineObjects, legends)
ax[0].set_ylabel('Selective Risk (%)')
ax[0].set_xlabel("Coverage")
ax[0].set_title('CIFAR100 ResNet34');

Imagenet_vit_BS = np.array([59.3,	54.4,	51.2,	47.3,	44.3,	40.9,	37.4,	34.4,	31.7])
Imagenet_vit_TS = np.array([57.8,	53.3,	49.9,	46.3,	42.8,	40.4,	37.1,	34.3,	31.6])
Imagenet_vit_MCS_TS = np.array ([58.4,	54.2,	50.9,	47.3,	44.2,	40.8,	38,	34.9,	32])
Imagenet_vit_all_error = np.array([Imagenet_vit_BS, Imagenet_vit_TS, Imagenet_vit_MCS_TS])

lineObjects = ax[1].plot(Coverage, Imagenet_vit_all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS TS']
ax[1].legend(lineObjects, legends)
ax[1].set_ylabel('Selective Risk (%)')
ax[1].set_xlabel("Coverage")
ax[1].set_title('ImageNet ViT');

Imagenet_swin_BS = np.array([52.5,	47.2,	43.2,	39.8,	37,	34.5,	32.3,	29.9,	27.8])
Imagenet_swin_TS = np.array([52.5,	47.6,	44,	40.1,	38,	34.9,	32.2,	30.1,	27.4])
Imagenet_swin_MCS_TS = np.array([55.1,	50,	46.2,	43.3,	40.1,	36.8,	34,	31.2,	27.8])
Imagenet_swin_all_error = np.array([Imagenet_swin_BS, Imagenet_swin_TS, Imagenet_swin_MCS_TS])

lineObjects = ax[2].plot(Coverage, Imagenet_swin_all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS TS']
ax[2].legend(lineObjects, legends)
ax[2].set_ylabel('Selective Risk (%)')
ax[2].set_xlabel("Coverage")
ax[2].set_title('ImageNet Swin Transformers');

Imagenet_rn_BS = np.array([76.5,	72.5,	68.8,	65.6,	62.1,	59.2,	56.6,	54.2,	51.3])
Imagenet_rn_TS = np.array([74.9,	71.2,	67.7,	64.3,	61.1,	58.3,	55.3,	53.2,	50.1])
Imagenet_rn_MCS_TS = np.array([75.4,	71.9,	68.9,	65.3,	62.5,	59.3,	56.2,	54.5,	50.9])
Imagenet_rn_all_error = np.array([Imagenet_rn_BS, Imagenet_rn_TS, Imagenet_rn_MCS_TS])


lineObjects = ax[3].plot(Coverage, Imagenet_rn_all_error.transpose(),marker='o',markersize=4)
legends = ['BS', 'TS', 'cwMCS TS']
ax[3].legend(lineObjects, legends)
ax[3].set_ylabel('Selective Risk (%)')
ax[3].set_xlabel("Coverage")
ax[3].set_title('ImageNet ResNet34');

plt.savefig("Risk_coverage_curve.pdf", bbox_inches='tight', dpi=1500)
